# %% [markdown]
# <a href="https://colab.research.google.com/github/charistyretta23/Sistem-panen-Kel.4/blob/main/Fitur_Input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def input_data():
    hasil_panen = float(input("Masukkan hasil panen (kg): "))
    harga_per_kg = float(input("Masukkan harga per kg: "))
    return hasil_panen, harga_per_kg
